# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = {
    "Maths": [45, 56, 67, 45, 78, 89, 90, 56, 67, 72,2344,-2131,1343,-13232,1234],
    "Science": [50, 60, 70, 55, 75, 85, 88, 58, 65, 70,3443,324324,122134,324324,24231]
}

df = pd.DataFrame(data)
df
# Out:
#     Maths  Science
# 0      45       50
# 1      56       60
# 2      67       70
# 3      45       55
# 4      78       75
# 5      89       85
# 6      90       88
# 7      56       58
# 8      67       65
# 9      72       70
# 10   2344     3443
# 11  -2131   324324
# 12   1343   122134
# 13 -13232   324324
# 14   1234    24231

# %%
mean_math=df['Maths'].mean()
mean_math
# Out:
# np.float64(-651.8)

# %%
m=df['Science'].mode()
m
# Out:
# 0        70
# 1    324324
# Name: Science, dtype: int64

# %%
var=df['Maths'].var()
var
# Out:
# np.float64(13008690.457142858)

# %%
stand=df['Maths'].std()
stand
# Out:
# np.float64(3606.756223692261)

# %%
# var=std*std

# %%
Q1 = df["Maths"].quantile(0.25)
Q3 = df["Maths"].quantile(0.75)
IQR = Q3 - Q1

print("IQR of Maths:", IQR)
# Out:
# IQR of Maths: 39.0

# %%
Q3
# Out:
# np.float64(89.5)

# %%
cov=df['Maths'].cov(df['Science'])
cov
# Out:
# np.float64(-304262229.5285714)

# %%
corr = df["Science"].corr(df["Maths"])
corr
# Out:
# np.float64(-0.7372211086711651)

# %%
plt.hist(df["Maths"])
plt.xlabel("Maths Marks")
plt.ylabel("Frequency")
plt.title("Histogram of Maths Marks")
plt.show()

# %%
plt.hist(df['Science'])
plt.show()

# %%
plt.boxplot(df["Maths"])
plt.title("Box Plot of Maths Marks")
plt.ylabel("Marks")
plt.show()

# %%
Q3
# Out:
# np.float64(89.5)

# %%
Q1
# Out:
# np.float64(50.5)

# %%
sns.boxplot(data=df)
plt.title("Box Plot of Maths & Science Marks")
plt.show()

# %%
df.describe()
# Out:
#               Maths        Science
# count     15.000000      15.000000
# mean    -651.800000   53275.466667
# std     3606.756224  114428.312055
# min   -13232.000000      50.000000
# 25%       50.500000      62.500000
# 50%       67.000000      75.000000
# 75%       89.500000   13837.000000
# max     2344.000000  324324.000000

# %%
df.head()
# Out:
#    Maths  Science
# 0     45       50
# 1     56       60
# 2     67       70
# 3     45       55
# 4     78       75
